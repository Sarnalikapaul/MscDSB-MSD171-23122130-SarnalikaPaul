# %%
pip install pandas
# Out:
# ...
#
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/2d/5e/9213ea10ac473e2437dc2cb17323ddc0999997e2713d6a0b683b10773994/pandas-2.1.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
pd.read_csv("random_items.csv")
# Out:
#        Item  Quantity  UnitPrice
# 0     Apple         5       0.50
# 1     Apple         5       0.50
# 2      Eggs        12       0.15
# 3      Rice         3       1.00
# 4    Banana         8       0.25
# ..      ...       ...        ...
# 95    Bread         1       2.00
# 96     Milk         2       1.50
# 97  Chicken         2       5.00
# 98  Chicken         2       5.00
# 99  Chicken         2       5.00
#
# [100 rows x 3 columns]

# %%
pd.read_csv("submission.csv")
# Out:
#      Unnamed: 0  data
# 0             0     0
# 1             1     1
# 2             2     2
# 3             3     3
# 4             4     4
# ..          ...   ...
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999
#
# [1000 rows x 2 columns]

# %%
a= pd.read_csv("submission.csv")

# %%
a.head(4)#to print how many rows you want
# Out:
#    Unnamed: 0  data
# 0           0     0
# 1           1     1
# 2           2     2
# 3           3     3

# %%
a.tail(34)
# Out:
#      Unnamed: 0  data
# 966         966   966
# 967         967   967
# 968         968   968
# 969         969   969
# 970         970   970
# 971         971   971
# 972         972   972
# 973         973   973
# 974         974   974
# 975         975   975
# 976         976   976
# 977         977   977
# 978         978   978
# 979         979   979
# 980         980   980
# 981         981   981
# 982         982   982
# 983         983   983
# 984         984   984
# 985         985   985
# 986         986   986
# 987         987   987
# 988         988   988
# 989         989   989
# 990         990   990
# 991         991   991
# 992         992   992
# 993         993   993
# 994         994   994
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999

# %% [markdown]
# create a class pandas_name that will help you to read csv file and print the top?bottom n rows in the file(outline)

# %% [markdown]
# class pandas_name:
#    init ()#stores the data
#    read_csv()#reads a csv file
#    head()#prints the top n rows
#    tail()#prints the bottom n rows
